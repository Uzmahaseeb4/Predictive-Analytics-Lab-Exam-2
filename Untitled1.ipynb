# %% [markdown]
# <a href="https://colab.research.google.com/github/Uzmahaseeb4/Predictive-Analytics-Lab-Exam-2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Load dataset
df = pd.read_csv("/content/Lab_Exam_binary_classification_dataset.csv")

# ------------------ EDA ------------------
print("Shape:", df.shape)
print("\nMissing values:\n", df.isnull().sum())
print("\nData types:\n", df.dtypes)
print("\nSummary:\n", df.describe())
print("\nTarget distribution:\n", df['Target'].values)

# Binary Classification using Logistic Regression
# Includes EDA, preprocessing, model building, evaluation, and decision boundary



# ------------------ Preprocessing ------------------
df = df.dropna()
df['Target'] = df['Target'].map({'Yes': 1, 'No': 0})

# Features and target
X = df[['Feature1', 'Feature2']]
y = df['Target']

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ------------------ Model ------------------
model = LogisticRegression(class_weight='balanced')
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# ------------------ Evaluation ------------------
print("\nAccuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# ------------------ Decision Boundary ------------------
X_scaled = scaler.fit_transform(X)

model.fit(X_scaled, y)

x_min, x_max = X_scaled[:, 0].min() - 1, X_scaled[:, 0].max() + 1
y_min, y_max = X_scaled[:, 1].min() - 1, X_scaled[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
                     np.arange(y_min, y_max, 0.01))

Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.3)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y)
plt.xlabel("Feature1")
plt.ylabel("Feature2")
plt.title("Decision Boundary")
plt.show()
# Out:
# Shape: (1020, 3)
#
# Missing values:
#  Feature1     0
# Feature2     0
# Target      20
# dtype: int64
#
# Data types:
#  Feature1    float64
# Feature2      int64
# Target       object
# dtype: object
#
# Summary:
#             Feature1     Feature2
# count   1020.000000  1020.000000
# mean      11.436679   520.988235
# std      313.061049    69.793442
# min        1.250000   400.000000
# 25%        1.450000   464.000000
# 50%        1.637500   520.000000
# 75%        1.828125   584.000000
# max    10000.000000   640.000000
#
# Target distribution:
#  ['Yes' 'No' 'Yes' ... 'No' 'No' 'No']
#
# Accuracy: 0.535
#
# Confusion Matrix:
#  [[82 74]
#  [19 25]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.53      0.64       156
#            1       0.25      0.57      0.35        44
#
#     accuracy                           0.54       200
#    macro avg       0.53      0.55      0.49       200
# ...

# %% [markdown]
# # Task
# `value_counts()` in the `print` statement.

# %% [markdown]
# ## modify_code
#
# ### Subtask:
# Fix the SyntaxError by completing the `value_counts()` function call in the `print` statement.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# - A `SyntaxError` was identified in the code, stemming from an incomplete call to the `value_counts()` function within a `print` statement.
#
# ### Insights or Next Steps
# - The `SyntaxError` was successfully resolved by completing the `value_counts()` function call in the `print` statement, allowing the code to execute without errors.
